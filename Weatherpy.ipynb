# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import openweathermapy as owm
import warnings

# Import API key
from config_weather import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_df = pd.DataFrame({"City":cities})
len(cities_df)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df["Country"] = ""
cities_df["Lat"] = ""
cities_df["Lon"] = ""
cities_df["Temperature"] = ""
cities_df["Humidity(%)"] = ""
cities_df["Cloudiness(%)"] = ""
cities_df["Wind Speed"] = ""
city_subset = cities_df.head()
city_subset
# Out:
#           City Country Lat Lon Temperature Humidity(%) Cloudiness(%)  \
# 0      marcona
# 1         brae
# 2    busselton
# 3       casper
# 4  bandarbeyla
#
#   Wind Speed
# 0
# 1
# 2
# 3
# 4

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"

for row in cities_df.itertuples():
    city = cities_df.at[row.Index,'City']
    params = {"q": city,
              "appid" : api_key,
             }
    params['keyword'] = city
    target_url = requests.get(base_url,params=params).json()
    
    #if(target_url["cod"] == 200):
    
    if(target_url.get("name")):
        print(f"Processing Record {row.Index} | {city}")
        cities_df.at[row.Index,"Country"] = target_url.get("sys").get("country")
        cities_df.at[row.Index,"Lat"] = target_url.get("coord").get("lat")
        cities_df.at[row.Index,"Lon"] = target_url.get("coord").get("lon")
        cities_df.at[row.Index,"Temperature"] = target_url.get("main").get("temp")
        cities_df.at[row.Index,"Humidity(%)"] = target_url.get("main").get("humidity")
        cities_df.at[row.Index,"Cloudiness(%)"] = target_url.get("clouds").get("all")
        cities_df.at[row.Index,"Wind Speed"] = target_url.get("wind").get("speed")
    else:
        print(f"City not found. Skipping...")
# Out:
# City not found. Skipping...
# Processing Record 1 | brae
# Processing Record 2 | busselton
# Processing Record 3 | casper
# Processing Record 4 | bandarbeyla
# Processing Record 5 | port elizabeth
# Processing Record 6 | bluff
# Processing Record 7 | cayenne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 | ushuaia
# Processing Record 11 | adrar
# Processing Record 12 | padang
# Processing Record 13 | saint-philippe
# Processing Record 14 | gayeri
# City not found. Skipping...
# Processing Record 16 | waingapu
# Processing Record 17 | punta arenas
# City not found. Skipping...
# Processing Record 19 | sorong
# Processing Record 20 | miyakonojo
# Processing Record 21 | bambous virieux
# Processing Record 22 | puerto ayora
# Processing Record 23 | roseburg
# Processing Record 24 | qaanaaq
# Processing Record 25 | casa nova
# Processing Record 26 | nikolskoye
# City not found. Skipping...
# Processing Record 28 | lagoa
# Processing Record 29 | vao
# Processing Record 30 | chikwawa
# Processing Record 31 | atuona
# Processing Record 32 | hobart
# Processing Record 33 | vardo
# Processing Record 34 | zaraza
# Processing Record 35 | arraial do cabo
# Processing Record 36 | esperance
# Processing Record 37 | carnarvon
# Processing Record 38 | tarakan
# Processing Record 39 | port alfred
# Processing Record 40 | kavieng
# Processing Record 41 | victoria
# Processing Record 42 | aripuana
# Processing Record 43 | upernavik
# City not found. Skipping...
# Processing Record 45 | bunol
# Processing Record 46 | leningradskiy
# Processing Record 47 | ambon
# Processing Record 48 | novaya igirma
# City not found. Skipping...
# Processing Record 50 | lakatoro
# Processing Record 51 | talnakh
# Processing Record 52 | pell city
# Processing Record 53 | nevsehir
# Processing Record 54 | jamestown
# Processing Record 55 | barrow
# Processing Record 56 | tuatapere
# Processing Record 57 | nome
# City not found. Skipping...
# Processing Record 59 | galle
# City not found. Skipping...
# Processing Record 61 | nanton
# City not found. Skipping...
# Processing Record 63 | ribeira grande
# Processing Record 64 | hithadhoo
# Processing Record 65 | tuktoyaktuk
# Processing Record 66 | vila velha
# Processing Record 67 | albany
# Processing Record 68 | bodden town
# Processing Record 69 | kahului
# Processing Record 70 | new norfolk
# Processing Record 71 | dubti
# Processing Record 72 | dikson
# Processing Record 73 | kizukuri
# Processing Record 74 | longyearbyen
# Processing Record 75 | port macquarie
# City not found. Skipping...
# Processing Record 77 | tessalit
# Processing Record 78 | turochak
# Processing Record 79 | kodiak
# Processing Record 80 | avarua
# Processing Record 81 | aberystwyth
# Processing Record 82 | medicine hat
# Processing Record 83 | antalaha
# Processing Record 84 | romhany
# Processing Record 85 | rikitea
# Processing Record 86 | bilma
# City not found. Skipping...
# Processing Record 88 | airai
# Processing Record 89 | fenoarivo
# Processing Record 90 | hervey bay
# Processing Record 91 | grindavik
# Processing Record 92 | sokolo
# Processing Record 93 | chokurdakh
# Processing Record 94 | hermanus
# Processing Record 95 | torbay
# Processing Record 96 | aksarka
# Processing Record 97 | portland
# Processing Record 98 | narsaq
# City not found. Skipping...
# Processing Record 100 | kolyvan
# Processing Record 101 | vaini
# Processing Record 102 | severo-kurilsk
# Processing Record 103 | georgetown
# Processing Record 104 | faya
# Processing Record 105 | chuy
# Processing Record 106 | east london
# City not found. Skipping...
# Processing Record 108 | cidreira
# Processing Record 109 | maningrida
# Processing Record 110 | kuytun
# Processing Record 111 | cairns
# Processing Record 112 | jinchang
# Processing Record 113 | san carlos de bariloche
# Processing Record 114 | kubachi
# Processing Record 115 | tasiilaq
# Processing Record 116 | yellowknife
# Processing Record 117 | sydney mines
# Processing Record 118 | kropotkin
# Processing Record 119 | harper
# Processing Record 120 | riyadh
# Processing Record 121 | waddan
# Processing Record 122 | mahebourg
# Processing Record 123 | caravaggio
# Processing Record 124 | thompson
# Processing Record 125 | lucea
# Processing Record 126 | mataura
# Processing Record 127 | pemberton
# Processing Record 128 | tiverton
# Processing Record 129 | lorengau
# Processing Record 130 | albemarle
# Processing Record 131 | cape town
# Processing Record 132 | piacabucu
# Processing Record 133 | wawa
# Processing Record 134 | christchurch
# Processing Record 135 | alice springs
# Processing Record 136 | hilo
# Processing Record 137 | potcoava
# Processing Record 138 | los llanos de aridane
# Processing Record 139 | ahipara
# City not found. Skipping...
# Processing Record 141 | samarai
# Processing Record 142 | manuk mangkaw
# Processing Record 143 | nanortalik
# City not found. Skipping...
# Processing Record 145 | vila franca do campo
# Processing Record 146 | nosy varika
# Processing Record 147 | ostrovnoy
# Processing Record 148 | gizo
# Processing Record 149 | dauriya
# Processing Record 150 | tashla
# Processing Record 151 | provideniya
# Processing Record 152 | lavrentiya
# City not found. Skipping...
# Processing Record 154 | krasnogorskoye
# Processing Record 155 | dingle
# Processing Record 156 | maceio
# Processing Record 157 | codrington
# Processing Record 158 | lebu
# Processing Record 159 | pozo colorado
# City not found. Skipping...
# Processing Record 161 | vermillion
# Processing Record 162 | mount gambier
# Processing Record 163 | lasa
# City not found. Skipping...
# Processing Record 165 | geraldton
# Processing Record 166 | saint-francois
# Processing Record 167 | port lincoln
# Processing Record 168 | biltine
# Processing Record 169 | tahoua
# Processing Record 170 | nador
# Processing Record 171 | arica
# Processing Record 172 | clyde river
# Processing Record 173 | smoky lake
# Processing Record 174 | oktyabrskoye
# Processing Record 175 | arlit
# City not found. Skipping...
# Processing Record 177 | husavik
# Processing Record 178 | fairbanks
# Processing Record 179 | uribia
# Processing Record 180 | mehamn
# Processing Record 181 | chone
# Processing Record 182 | pando
# Processing Record 183 | caravelas
# City not found. Skipping...
# Processing Record 185 | san joaquin
# Processing Record 186 | ereymentau
# Processing Record 187 | norman wells
# Processing Record 188 | pevek
# Processing Record 189 | maragogi
# Processing Record 190 | mar del plata
# Processing Record 191 | ust-barguzin
# Processing Record 192 | itacare
# Processing Record 193 | sao filipe
# Processing Record 194 | hearst
# Processing Record 195 | khatanga
# Processing Record 196 | nouna
# Processing Record 197 | havoysund
# Processing Record 198 | salinopolis
# Processing Record 199 | katangli
# Processing Record 200 | veraval
# Processing Record 201 | hami
# Processing Record 202 | moerai
# Processing Record 203 | kloulklubed
# Processing Record 204 | hay river
# Processing Record 205 | russell
# Processing Record 206 | terney
# Processing Record 207 | inuvik
# Processing Record 208 | ilulissat
# Processing Record 209 | kapaa
# Processing Record 210 | sungai besar
# Processing Record 211 | liwale
# Processing Record 212 | nynashamn
# City not found. Skipping...
# Processing Record 214 | batemans bay
# Processing Record 215 | kasama
# Processing Record 216 | aswan
# Processing Record 217 | bethel
# Processing Record 218 | west wendover
# Processing Record 219 | tairua
# Processing Record 220 | saint george
# Processing Record 221 | alofi
# Processing Record 222 | zasosna
# Processing Record 223 | kemerovo
# Processing Record 224 | jacareacanga
# Processing Record 225 | okhotsk
# Processing Record 226 | kisangani
# Processing Record 227 | labuan
# City not found. Skipping...
# Processing Record 229 | necochea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 232 | florianopolis
# Processing Record 233 | naze
# Processing Record 234 | udachnyy
# Processing Record 235 | zhuhai
# Processing Record 236 | bambanglipuro
# Processing Record 237 | takoradi
# Processing Record 238 | sao pedro do sul
# Processing Record 239 | kutum
# Processing Record 240 | benjamin aceval
# Processing Record 241 | anstruther
# Processing Record 242 | kaitangata
# Processing Record 243 | tongren
# Processing Record 244 | randolph
# City not found. Skipping...
# Processing Record 246 | bay roberts
# Processing Record 247 | tres arroyos
# Processing Record 248 | sisimiut
# Processing Record 249 | punta alta
# Processing Record 250 | bathsheba
# Processing Record 251 | ponta delgada
# Processing Record 252 | aliwal north
# Processing Record 253 | amahai
# Processing Record 254 | san andres del rabanedo
# Processing Record 255 | grand gaube
# City not found. Skipping...
# Processing Record 257 | puerto narino
# Processing Record 258 | hofn
# Processing Record 259 | igarka
# Processing Record 260 | iqaluit
# Processing Record 261 | coihaique
# Processing Record 262 | saskylakh
# Processing Record 263 | sao felix do xingu
# Processing Record 264 | pachmarhi
# Processing Record 265 | atasu
# Processing Record 266 | neiafu
# Processing Record 267 | libungan
# Processing Record 268 | tiarei
# Processing Record 269 | luderitz
# Processing Record 270 | pedernales
# Processing Record 271 | aleksandro-nevskiy
# Processing Record 272 | stromness
# Processing Record 273 | nisia floresta
# City not found. Skipping...
# Processing Record 275 | limulunga
# Processing Record 276 | kirakira
# Processing Record 277 | manokwari
# Processing Record 278 | hasaki
# Processing Record 279 | ust-karsk
# Processing Record 280 | muhos
# Processing Record 281 | broken hill
# Processing Record 282 | petropavlovsk-kamchatskiy
# Processing Record 283 | boguchany
# Processing Record 284 | rassvet
# Processing Record 285 | san patricio
# Processing Record 286 | glens falls
# Processing Record 287 | groningen
# Processing Record 288 | mopti
# Processing Record 289 | taoudenni
# Processing Record 290 | pocone
# Processing Record 291 | cartagena
# Processing Record 292 | saldanha
# Processing Record 293 | mokhsogollokh
# Processing Record 294 | teya
# Processing Record 295 | tezu
# Processing Record 296 | smithers
# Processing Record 297 | ancud
# Processing Record 298 | huarmey
# Processing Record 299 | isangel
# Processing Record 300 | shestakovo
# Processing Record 301 | arsk
# Processing Record 302 | cabra
# Processing Record 303 | kang
# Processing Record 304 | xinzhou
# Processing Record 305 | ponta do sol
# Processing Record 306 | shingu
# Processing Record 307 | castro
# Processing Record 308 | gigmoto
# Processing Record 309 | bakchar
# Processing Record 310 | cabo san lucas
# Processing Record 311 | souillac
# Processing Record 312 | newport
# Processing Record 313 | bela
# City not found. Skipping...
# Processing Record 315 | tual
# Processing Record 316 | zhezkazgan
# Processing Record 317 | camalu
# Processing Record 318 | kiunga
# Processing Record 319 | napoleon
# Processing Record 320 | butaritari
# Processing Record 321 | ushtobe
# Processing Record 322 | meulaboh
# Processing Record 323 | lata
# Processing Record 324 | touros
# City not found. Skipping...
# Processing Record 326 | eyl
# Processing Record 327 | grand-lahou
# Processing Record 328 | hirara
# Processing Record 329 | sal rei
# Processing Record 330 | deogarh
# Processing Record 331 | kavaratti
# Processing Record 332 | kangaba
# Processing Record 333 | tura
# Processing Record 334 | fortuna
# Processing Record 335 | nelson bay
# Processing Record 336 | san vicente
# Processing Record 337 | kayasula
# Processing Record 338 | buala
# Processing Record 339 | vegachi
# Processing Record 340 | cap malheureux
# Processing Record 341 | powell river
# Processing Record 342 | pontes e lacerda
# Processing Record 343 | ambilobe
# Processing Record 344 | talaya
# Processing Record 345 | coswig
# City not found. Skipping...
# Processing Record 347 | birin
# Processing Record 348 | katsuura
# Processing Record 349 | derzhavinsk
# Processing Record 350 | camacupa
# Processing Record 351 | dalvik
# Processing Record 352 | sarakhs
# Processing Record 353 | brenham
# Processing Record 354 | nishihara
# Processing Record 355 | nantucket
# City not found. Skipping...
# Processing Record 357 | viedma
# Processing Record 358 | aklavik
# Processing Record 359 | vung tau
# Processing Record 360 | broome
# Processing Record 361 | henties bay
# Processing Record 362 | baruun-urt
# Processing Record 363 | guerrero negro
# Processing Record 364 | southbridge
# Processing Record 365 | warri
# Processing Record 366 | kalmunai
# Processing Record 367 | oussouye
# Processing Record 368 | taguatinga
# Processing Record 369 | baykit
# Processing Record 370 | arys
# Processing Record 371 | cherskiy
# Processing Record 372 | upington
# Processing Record 373 | sola
# Processing Record 374 | tyukhtet
# Processing Record 375 | xining
# Processing Record 376 | kenora
# City not found. Skipping...
# Processing Record 378 | nhulunbuy
# Processing Record 379 | vostok
# Processing Record 380 | flinders
# Processing Record 381 | faanui
# City not found. Skipping...
# Processing Record 383 | bolzano
# Processing Record 384 | macklin
# City not found. Skipping...
# Processing Record 386 | bredasdorp
# City not found. Skipping...
# Processing Record 388 | vytegra
# Processing Record 389 | payyannur
# Processing Record 390 | tecoanapa
# Processing Record 391 | tiksi
# Processing Record 392 | starkville
# City not found. Skipping...
# Processing Record 394 | ternate
# Processing Record 395 | fuling
# Processing Record 396 | nouadhibou
# Processing Record 397 | havre-saint-pierre
# Processing Record 398 | zwedru
# Processing Record 399 | achhnera
# Processing Record 400 | susangerd
# Processing Record 401 | zhuzhou
# Processing Record 402 | bubaque
# Processing Record 403 | lompoc
# Processing Record 404 | mount isa
# Processing Record 405 | laguna
# City not found. Skipping...
# Processing Record 407 | namibe
# Processing Record 408 | kruisfontein
# Processing Record 409 | sorland
# Processing Record 410 | pedasi
# Processing Record 411 | port augusta
# Processing Record 412 | pangkalanbuun
# Processing Record 413 | impfondo
# Processing Record 414 | freeport
# Processing Record 415 | folldal
# Processing Record 416 | sitka
# Processing Record 417 | rapar
# Processing Record 418 | makaryev
# Processing Record 419 | barranca
# Processing Record 420 | port blair
# Processing Record 421 | samana
# Processing Record 422 | port hedland
# Processing Record 423 | victor harbor
# Processing Record 424 | virpur
# City not found. Skipping...
# Processing Record 426 | yining
# City not found. Skipping...
# Processing Record 428 | marsh harbour
# Processing Record 429 | santa maria
# Processing Record 430 | conakry
# Processing Record 431 | black river
# Processing Record 432 | avera
# Processing Record 433 | lodja
# Processing Record 434 | san quintin
# Processing Record 435 | bajil
# City not found. Skipping...
# Processing Record 437 | solnechnyy
# Processing Record 438 | klaebu
# Processing Record 439 | soyo
# Processing Record 440 | mingyue
# Processing Record 441 | buraydah
# City not found. Skipping...
# Processing Record 443 | acapulco
# Processing Record 444 | mackenzie
# Processing Record 445 | port shepstone
# Processing Record 446 | topolobampo
# Processing Record 447 | goderich
# Processing Record 448 | plouzane
# Processing Record 449 | dingzhou
# Processing Record 450 | traverse city
# Processing Record 451 | chumikan
# Processing Record 452 | gillette
# Processing Record 453 | tieling
# Processing Record 454 | walvis bay
# Processing Record 455 | komsomolskiy
# Processing Record 456 | bontang
# Processing Record 457 | nizhneudinsk
# Processing Record 458 | muros
# Processing Record 459 | jizan
# Processing Record 460 | vadum
# Processing Record 461 | manicore
# Processing Record 462 | itoman
# Processing Record 463 | dongsheng
# Processing Record 464 | masterton
# Processing Record 465 | nikolsk
# Processing Record 466 | chau doc
# Processing Record 467 | rorvik
# Processing Record 468 | saint-pierre
# Processing Record 469 | coquimbo
# Processing Record 470 | shubarkuduk
# City not found. Skipping...
# Processing Record 472 | nakama
# Processing Record 473 | waipawa
# Processing Record 474 | kosa
# Processing Record 475 | warrnambool
# Processing Record 476 | sturgis
# Processing Record 477 | belyy yar
# Processing Record 478 | hobyo
# Processing Record 479 | bingol
# Processing Record 480 | molepolole
# City not found. Skipping...
# Processing Record 482 | olinda
# Processing Record 483 | panzhihua
# Processing Record 484 | vancouver
# Processing Record 485 | rocha
# Processing Record 486 | springbok
# Processing Record 487 | coalinga
# Processing Record 488 | haines junction
# Processing Record 489 | jumla
# Processing Record 490 | dukat
# Processing Record 491 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 493 | vernon
# Processing Record 494 | gat
# City not found. Skipping...
# Processing Record 496 | karasburg
# Processing Record 497 | ilhabela
# Processing Record 498 | pitkyaranta
# Processing Record 499 | esso
# City not found. Skipping...
# Processing Record 501 | verkhnevilyuysk
# Processing Record 502 | mechetinskaya
# Processing Record 503 | micheweni
# Processing Record 504 | caernarfon
# Processing Record 505 | erzin
# Processing Record 506 | atar
# Processing Record 507 | coari
# Processing Record 508 | kamenka
# Processing Record 509 | astana
# Processing Record 510 | bograd
# Processing Record 511 | half moon bay
# Processing Record 512 | pacific grove
# Processing Record 513 | bilibino
# Processing Record 514 | kyshtovka
# Processing Record 515 | girona
# Processing Record 516 | cortez
# Processing Record 517 | rawson
# Processing Record 518 | sawankhalok
# Processing Record 519 | estacion coahuila
# City not found. Skipping...
# Processing Record 521 | camabatela
# Processing Record 522 | yerbogachen
# Processing Record 523 | gisborne
# Processing Record 524 | namtsy
# Processing Record 525 | santa cruz
# Processing Record 526 | flin flon
# Processing Record 527 | robertson
# Processing Record 528 | talas
# Processing Record 529 | prince rupert
# Processing Record 530 | halifax
# Processing Record 531 | valleyview
# Processing Record 532 | emilio carranza
# Processing Record 533 | guntakal
# Processing Record 534 | seoul
# Processing Record 535 | pachino
# Processing Record 536 | amapa
# Processing Record 537 | port keats
# Processing Record 538 | iracoubo
# Processing Record 539 | sibolga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 542 | saurimo
# Processing Record 543 | marawi
# Processing Record 544 | sao francisco
# Processing Record 545 | enid
# Processing Record 546 | honiara
# Processing Record 547 | katikati
# City not found. Skipping...
# Processing Record 549 | harboore
# City not found. Skipping...
# Processing Record 551 | sur
# Processing Record 552 | saint anthony
# Processing Record 553 | sumoto
# Processing Record 554 | rovaniemi
# City not found. Skipping...
# Processing Record 556 | margate
# Processing Record 557 | taseyevo
# Processing Record 558 | katherine
# Processing Record 559 | yumen
# Processing Record 560 | taywarah
# Processing Record 561 | syke
# Processing Record 562 | zeya
# Processing Record 563 | general pico
# Processing Record 564 | kabin buri
# Processing Record 565 | nemuro
# Processing Record 566 | roald
# Processing Record 567 | hornepayne
# Processing Record 568 | svetlogorsk
# Processing Record 569 | richards bay
# City not found. Skipping...
# Processing Record 571 | mirnyy
# Processing Record 572 | ngunguru
# City not found. Skipping...
# Processing Record 574 | port hardy
# Processing Record 575 | hoorn
# Processing Record 576 | mogadishu
# Processing Record 577 | utete
# Processing Record 578 | corbu
# Processing Record 579 | tolmezzo
# Processing Record 580 | high level
# Processing Record 581 | hamilton
# Processing Record 582 | gdansk
# Processing Record 583 | lovozero
# Processing Record 584 | ixtapa
# Processing Record 585 | soure
# Processing Record 586 | mattersburg
# Processing Record 587 | halden
# Processing Record 588 | mecca
# Processing Record 589 | skjervoy
# Processing Record 590 | karratha
# Processing Record 591 | botwood
# Processing Record 592 | wattegama
# Processing Record 593 | daru
# City not found. Skipping...
# Processing Record 595 | kilindoni

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Output File (CSV)
cities_df.to_csv("cities_df.csv")
cities_df
# Out:
#                        City Country    Lat     Lon Temperature Humidity(%)  \
# 0                   marcona
# 1                      brae      GB   60.4   -1.35      279.15          90
# 2                 busselton      AU -33.64  115.35      282.58          65
# 3                    casper      US  42.87 -106.31      281.28          49
# 4               bandarbeyla      SO   9.49   50.81     298.893         100
# 5            port elizabeth      US  39.31  -74.98      282.97          49
# 6                     bluff      AU -23.58  149.07     294.393          90
# 7                   cayenne      GF   4.94  -52.33      301.15          74
# 8    grand river south east
# 9               nizhneyansk
# 10                  ushuaia      AR -54.81  -68.31      281.15          93
# 11                    adrar      DZ  27.87   -0.29      290.15          33
# 12                   padang      ID  -0.92  100.36     298.493         100
# 13           saint-philippe      CA  45.36  -73.48      275.06          93
# 14                   gayeri      BF  12.65    0.49     300.843          32
# 15                 bur gabo
# 16                 waingapu      ID  -9.65  120.26     296.743          96
# 17             punta arenas      CL -53.16  -70.91      288.15          47
# 18                 el wasta
# 19                   sorong      ID  -0.86  131.25     300.343         100
# 20               miyakonojo      JP  31.78  131.06      281.03          61
# 21          bambous virieux      MU -20.34   57.76       299.8          78
# 22             puerto ayora      EC  -0.74  -90.35      300.71          70
# 23                 roseburg      US  43.22 -123.34      284.58          76
# 24                  qaanaaq      GL  77.48  -69.36     240.743          77
# 25                casa nova      BR -11.77  -39.23     296.693          98
# 26               nikolskoye      RU   59.7   30.79      274.52          59
# 27                   azimur
# 28                    lagoa      PT  37.14   -8.45      287.31          77
# 29                      vao      EE   59.1   26.19     268.243          81
# ..                      ...     ...    ...     ...         ...         ...
# 566                   roald      NO  62.58    6.12      278.87          70
# 567              hornepayne      CA  49.22  -84.78     268.743          57
# 568             svetlogorsk      RU  53.14   59.15      270.15          92
# 569            richards bay      ZA -28.77   32.06     293.093         100
# 570            krasnoselkup
# 571                  mirnyy      RU  56.57   36.46     272.743          86
# 572                ngunguru      NZ -35.62   174.5      292.04          93
# 573                dzhusaly
# 574              port hardy      CA   50.7 -127.42      286.15          62
# 575                   hoorn      NL  52.65    5.07      280.55          93
# 576               mogadishu      SO   2.04   45.34     300.993          99
# 577                   utete      TZ  -7.99   38.76     298.343          90
# 578                   corbu      RO  44.41   28.66      282.09          61
# 579                tolmezzo      IT  46.41   13.02      284.02          66
# 580              high level      CA  58.52 -117.13      286.15          35
# 581                hamilton      BM   32.3  -64.78      293.66          73
# 582                  gdansk      PL  54.35   18.65      275.81          80
# 583                lovozero      RU  68.01   35.02     261.043          65
# 584                  ixtapa      MX  20.71 -105.21      300.97          45
# 585                   soure      PT  40.06   -8.63      285.88          54
# 586             mattersburg      AT  47.74    16.4      280.79          61
# 587                  halden      SE  59.12   11.39      278.36         100
# 588                   mecca      SA  21.43   39.83     289.243          71
# 589                skjervoy      NO  70.03   20.97      276.15          55
# 590                karratha      AU -20.74  116.85     301.543          69
# 591                 botwood      CA  49.14  -55.34       275.7          59
# 592               wattegama      LK   7.35   80.68     293.993          92
# 593                    daru      SL   7.99  -10.85     300.143          67
# 594                tsihombe
# 595               kilindoni      TZ  -7.91   39.67     301.493         100
#
#     Cloudiness(%) Wind Speed
# 0
# 1              48       16.5
# 2              48       7.92
# 3              90        2.1
# 4              92       3.27
# 5              40        9.8
# 6               0       2.77
# 7              20        6.2
# 8
# 9
# 10             75        3.6
# 11              0        4.6
# 12             68       1.67
# 13             90        5.1
# 14              0       2.47
# 15
# 16             20       2.37
# 17             40        4.6
# 18
# 19             92       2.52
# 20             75        3.6
# 21             40        5.1
# 22             20        3.6
# 23             90       1.77
# 24              0       5.22
# 25             56       1.97
# 26             90          4
# 27
# 28              0        2.1
# 29              8       1.22
# ..            ...        ...
# 566            75       12.3
# 567             0       3.72
# 568             0       1.27
# 569            48       1.17
# 570
# 571            92       8.97
# 572            64       1.42
# 573
# 574            75        6.2
# 575            90        4.6
# 576             0       8.87
# 577            24       1.62
# 578             0        3.1
# 579             5        2.6
# 580            40        3.6
# 581            75       11.3
# 582             0        0.5
# 583             8       1.67
# 584             5        5.7
# 585             0        1.5
# 586             0          1
# 587            92        7.2
# 588            24       1.22
# 589            75        7.7
# 590            92      10.47
# 591            90        8.7
# 592            20       1.27
# 593            68       2.42
# 594
# 595            32       4.07
#
# [596 rows x 8 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
d=datetime.datetime.today()
plt.scatter(pd.to_numeric(cities_df["Lat"]),pd.to_numeric(cities_df["Temperature"]),edgecolors="k",linewidths=1.00)
plt.title(f"City Latitude Vs. Max.Temperature ({d.strftime('%d/%m/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature (F)")
plt.grid()
plt.savefig("Lat_vs_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(pd.to_numeric(cities_df["Lat"]),pd.to_numeric(cities_df["Humidity(%)"]),edgecolors="k",linewidths=1.00)

plt.title(f"City Latitude Vs. Humidity ({d.strftime('%d/%m/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid()
plt.savefig("Lat_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(pd.to_numeric(cities_df["Lat"]),pd.to_numeric(cities_df["Cloudiness(%)"]),edgecolors="k",linewidths=1.00)
plt.title(f"City Latitude Vs. Cloudiness ({d.strftime('%d/%m/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid()
plt.savefig("Lat_vs_cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(pd.to_numeric(cities_df["Lat"]),pd.to_numeric(cities_df["Wind Speed"]),edgecolors="k",linewidths=1.00)
plt.title(f"City Latitude Vs. Wind Speed ({d.strftime('%d/%m/%Y')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("Lat_vs_windspeed.png")
